# %%
import json
import folium
import pandas as pd
from folium.plugins import MarkerCluster
import matplotlib.pyplot as plt

# %%
# %cd '/content/drive/MyDrive/멀티캠퍼스 5조/2.데이터'
# Out:
# /content/drive/.shortcut-targets-by-id/1Mz49-WiynxJxHmmXYuWSqduV3-jd-BC7/멀티캠퍼스 5조/2.데이터

# %%
df = pd.read_csv('서울시 병의원 위치 정보.csv', encoding = 'cp949')
df.head(2)
# Out:
#        기관ID                                        주소 병원분류 병원분류명 응급의료기관코드  \
# 0  A1120837  서울특별시 금천구 벚꽃로 286 삼성리더스타워 111~114호 (가산동)    C    의원     G099
# 1  A1104130          서울특별시 강남구 도산대로 118 (논현동 신사빌딩 2층)    C    의원     G099
#
#    응급의료기관코드명  응급실운영여부(1/2)                   비고  \
# 0  응급의료기관 이외             2  외과: 상시진료 내과는 당분간 휴진
# 1  응급의료기관 이외             2                비만클리닉
#
#                                               기관설명상세  \
# 0  서울시 송파구 문정동 장지동 법조단지 위례 가락동 가락시장역 위치 삼성서울병원 외래...
# 1               365일 진료 국민건강보험공단 검진 지정병원 점심시간 13~14시
#
#                         간이약도  ... 진료시간(목요일)S 진료시간(금요일)S 진료시간(토요일)S  \
# 0  방이역 1번출구 바로옆 굿모닝 신한증권 뒷건물  ...        900        900        900
# 1               신사역 1번 출구 인근  ...       1100       1100       1100
#
#    진료시간(일요일)S  진료시간(공휴일)S  우편번호1  우편번호2        병원경도       병원위도  \
# 0      1000.0      1000.0     85     11  126.884122  37.480394
# 1       900.0       900.0     60     38  127.021809  37.516604
#
#                     작업시간
# ...

# %%
df.iloc[0,:]
# Out:
# 기관ID                                                     A1120837
# 주소                       서울특별시 금천구 벚꽃로 286 삼성리더스타워 111~114호 (가산동)
# 병원분류                                                            C
# 병원분류명                                                          의원
# 응급의료기관코드                                                     G099
# 응급의료기관코드명                                               응급의료기관 이외
# 응급실운영여부(1/2)                                                    2
# 비고                                            외과: 상시진료 내과는 당분간 휴진
# 기관설명상세          서울시 송파구 문정동 장지동 법조단지 위례 가락동 가락시장역 위치 삼성서울병원 외래...
# 간이약도                                    방이역 1번출구 바로옆 굿모닝 신한증권 뒷건물
# 기관명                                                       가산기대찬의원
# 대표전화1                                                02-6267-2580
# 응급실전화                                                 02-920-5374
# 진료시간(월요일)C                                                   1930
# ...

# %%
hospital_df = df[['기관ID','기관명', '병원분류명','주소','병원경도','병원위도']]
hospital_df.head(2)
# Out:
#        기관ID      기관명 병원분류명                                        주소  \
# 0  A1120837  가산기대찬의원    의원  서울특별시 금천구 벚꽃로 286 삼성리더스타워 111~114호 (가산동)
# 1  A1104130  365엠씨의원    의원          서울특별시 강남구 도산대로 118 (논현동 신사빌딩 2층)
#
#          병원경도       병원위도
# 0  126.884122  37.480394
# 1  127.021809  37.516604

# %%
hospital_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18631 entries, 0 to 18630
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기관ID    18631 non-null  object
#  1   기관명     18631 non-null  object
#  2   병원분류명   18631 non-null  object
#  3   주소      18631 non-null  object
#  4   병원경도    18631 non-null  float64
#  5   병원위도    18631 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 873.5+ KB

# %%
hospital_df.기관ID.nunique()  # 중복 데이터 없음
# Out:
# 18631

# %%
hospital_df.병원분류명.unique()
# Out:
# array(['의원', '한방병원', '치과의원', '한의원', '치과병원', '병원', '요양병원', '종합병원', '기타',
#        '보건소', '기타(구급차)'], dtype=object)

# %%
hospital_df[hospital_df.병원분류명 == '종합병원'].head(3)
# Out:
#          기관ID                     기관명 병원분류명  \
# 149  A1100008  (학)고려대학교의과대학부속병원(안암병원)  종합병원
# 681  A1100018      재단법인베스티안재단베스티안서울병원  종합병원
# 934  A1100011           가톨릭대학교여의도성모병원  종합병원
#
#                                          주소        병원경도       병원위도
# 149         서울특별시 성북구 고려대로 73 고려대병원 (안암동5가)  127.026471  37.587156
# 681  서울특별시 강남구 도곡로 429 (대치동 베스티안병원 2층일부 제외)  127.057267  37.498071
# 934        서울특별시 영등포구 63로 10 여의도성모병원 (여의도동)  126.936731  37.518272

# %%
# 푸르메재단넥슨어린이재활병원
hospital_df[hospital_df.기관명.str.contains('푸르메재단')]
# Out:
#            기관ID             기관명 병원분류명  \
# 17368  A1118761  푸르메재단넥슨어린이재활병원  요양병원
#
#                                                      주소        병원경도       병원위도
# 17368  서울특별시 마포구 월드컵북로 494 지하1층~7층 (상암동 푸르메재단넥슨어린이재활병원)  126.880519  37.584647

# %% [markdown]
# 1. 종합병원과 목적지 위치 비교

# %%
df1 = pd.concat([hospital_df[hospital_df.병원분류명 == '종합병원'], hospital_df[hospital_df.기관명.str.contains('푸르메재단')]])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 149 to 17368
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   기관ID    58 non-null     object
#  1   기관명     58 non-null     object
#  2   병원분류명   58 non-null     object
#  3   주소      58 non-null     object
#  4   병원경도    58 non-null     float64
#  5   병원위도    58 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 3.2+ KB

# %%
df1.reset_index(drop = True, inplace = True)

# %%
geo_str= json.load(open("/content/drive/MyDrive/멀티캠퍼스 5조/2.데이터/json/skorea_municipalities_geo_simple.json",encoding = 'utf-8'))

# %%
map = folium.Map(location = [37.5502, 126.982], zoom_start=11)
marker_cluster = MarkerCluster().add_to(map) 

for i in range(len(df1)):
    folium.Circle(
        location = [df1.loc[i,'병원위도'], df1.loc[i,'병원경도']],
        tooltip = df1.loc[i, '기관명'],
        radius= 200
        ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
