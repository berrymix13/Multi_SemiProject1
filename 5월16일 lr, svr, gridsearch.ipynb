# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
import os
import json
import datetime
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/'멀티캠퍼스 5조'/2.데이터

df = pd.read_csv('/content/drive/MyDrive/멀티캠퍼스 5조/2.데이터/2022년4월만_공휴일_강수량.csv')
df.info()

# %%
plus= (df.대기시간 >0) 
df2=df.loc[plus]
df2.info()

# %%
df2=df2[['대기시간','운행차량수','시간대_30분','평균속도','강수량','적설량','언급량','공휴일']]

# %%
from sklearn.model_selection import train_test_split

X = np.array(df2[['운행차량수','시간대_30분','평균속도','강수량','적설량','언급량','공휴일']])
y = np.array(df2['대기시간'])


X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=2022)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.08698089822413224

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
param_grid = [{'kernel': ['linear'], 'C':[0.1,1,3]}]
svm_reg=SVR()

grid_search=GridSearchCV(svm_reg,param_grid,cv=3,scoring='neg_mean_squared_error',verbose=2)
grid_search.fit(X_train_std, y_train)
# Out:
# Fitting 3 folds for each of 3 candidates, totalling 9 fits
# [CV] END ...............................C=0.1, kernel=linear; total time= 1.4min
# [CV] END ...............................C=0.1, kernel=linear; total time= 2.1min
# [CV] END ...............................C=0.1, kernel=linear; total time= 2.2min
# [CV] END .................................C=1, kernel=linear; total time= 1.5min
# [CV] END .................................C=1, kernel=linear; total time= 1.5min
# [CV] END .................................C=1, kernel=linear; total time= 1.5min
# [CV] END .................................C=3, kernel=linear; total time= 1.5min
# [CV] END .................................C=3, kernel=linear; total time= 1.5min
# [CV] END .................................C=3, kernel=linear; total time= 1.6min
# GridSearchCV(cv=3, estimator=SVR(),
#              param_grid=[{'C': [0.1, 1, 3], 'kernel': ['linear']}],
#              scoring='neg_mean_squared_error', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'C': 3, 'kernel': 'linear'}

# %%
negative_mse=grid_search.best_score_
rmse=np.sqrt(-negative_mse)
rmse
# Out:
# 20.577021359102307

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
param_grid = [{'kernel': ['linear'], 'C':[2.5,3,5]}]
svm_reg=SVR()

grid_search=GridSearchCV(svm_reg,param_grid,cv=2,scoring='neg_mean_squared_error',verbose=2)
grid_search.fit(X_train_std, y_train)
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [CV] END ...............................C=2.5, kernel=linear; total time= 1.0min
# [CV] END ...............................C=2.5, kernel=linear; total time= 1.0min
# [CV] END .................................C=3, kernel=linear; total time= 1.0min
# [CV] END .................................C=3, kernel=linear; total time= 1.0min
# [CV] END .................................C=5, kernel=linear; total time= 1.1min
# [CV] END .................................C=5, kernel=linear; total time= 1.1min
# GridSearchCV(cv=2, estimator=SVR(),
#              param_grid=[{'C': [2.5, 3, 5], 'kernel': ['linear']}],
#              scoring='neg_mean_squared_error', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'C': 5, 'kernel': 'linear'}

# %%
negative_mse=grid_search.best_score_
rmse=np.sqrt(-negative_mse)
rmse
# Out:
# 20.57477561791219

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
param_grid = [{'kernel': ['linear'], 'C':[5,7,10]}]
svm_reg=SVR()

grid_search=GridSearchCV(svm_reg,param_grid,cv=2,scoring='neg_mean_squared_error',verbose=2)
grid_search.fit(X_train_std, y_train)
# Out:
# Fitting 2 folds for each of 3 candidates, totalling 6 fits
# [CV] END .................................C=5, kernel=linear; total time= 1.1min
# [CV] END .................................C=5, kernel=linear; total time= 1.1min
# [CV] END .................................C=7, kernel=linear; total time= 1.1min
# [CV] END .................................C=7, kernel=linear; total time= 1.1min
# [CV] END ................................C=10, kernel=linear; total time= 1.1min
# [CV] END ................................C=10, kernel=linear; total time= 1.1min
# GridSearchCV(cv=2, estimator=SVR(),
#              param_grid=[{'C': [5, 7, 10], 'kernel': ['linear']}],
#              scoring='neg_mean_squared_error', verbose=2)

# %%
grid_search.best_params_
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
negative_mse=grid_search.best_score_
rmse=np.sqrt(-negative_mse)
rmse
# Out:
# 20.57476089615689

# %%
svm_reg=SVR()

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
param_grid = [{'kernel': ['rbf'], 'C':[3,5,10],'gamma':[0.01,0.03,0.1]}]
svm_reg=SVR()

grid_search=GridSearchCV(svm_reg,param_grid,cv=2,scoring='neg_mean_squared_error',verbose=2)
grid_search.fit(X_train_std, y_train)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# [CV] END ........................C=3, gamma=0.01, kernel=rbf; total time= 2.0min
# [CV] END ........................C=3, gamma=0.01, kernel=rbf; total time= 2.0min
# [CV] END ........................C=3, gamma=0.03, kernel=rbf; total time= 2.0min
# [CV] END ........................C=3, gamma=0.03, kernel=rbf; total time= 2.0min
# [CV] END .........................C=3, gamma=0.1, kernel=rbf; total time= 2.0min
# [CV] END .........................C=3, gamma=0.1, kernel=rbf; total time= 2.0min
# [CV] END ........................C=5, gamma=0.01, kernel=rbf; total time= 2.0min
# [CV] END ........................C=5, gamma=0.01, kernel=rbf; total time= 2.0min
# [CV] END ........................C=5, gamma=0.03, kernel=rbf; total time= 2.0min
# [CV] END ........................C=5, gamma=0.03, kernel=rbf; total time= 2.0min
# [CV] END .........................C=5, gamma=0.1, kernel=rbf; total time= 2.0min
# ...

# %%
grid_search.best_params_
# Out:
# {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
negative_mse=grid_search.best_score_
rmse=np.sqrt(-negative_mse)
rmse
# Out:
# 18.43672774859094

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
param_grid = [{'kernel': ['linear'], 'C':[10,30,100]}]
svm_reg=SVR()

grid_search=GridSearchCV(svm_reg,param_grid,cv=5,scoring='neg_mean_squared_error',verbose=2)
grid_search.fit(X_train, y_train)


grid_search.best_params_

negative_mse=grid_search.best_score_
rmse=np.sqrt(-negative_mse)
rmse

#GridSearchCV(cv=5, estimator=SVR(),
#             param_grid=[{'C': [10, 30, 100], 'kernel': ['linear']}],
#             scoring='neg_mean_squared_error', verbose=2)
#grid_search.best_params_={'C': 10, 'kernel': 'linear'}
#RMSE=20.575678954578787

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
svm_reg=SVR(kernel='linear',C=10)
svm_reg.fit(X_train, y_train)
r_2 = svm_reg.score(X_test, y_test)

print(r_2)
# Out:
# 0.045807440934091725
